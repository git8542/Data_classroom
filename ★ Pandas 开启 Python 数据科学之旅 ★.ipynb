# %% [markdown]
# https://medium.com/datainpoint/%E5%BE%9E-pandas-%E9%96%8B%E5%A7%8B-python-%E8%88%87%E8%B3%87%E6%96%99%E7%A7%91%E5%AD%B8%E4%B9%8B%E6%97%85-8dee36796d4a

# %%
import pandas as pd

# %%
xlsx_file = "https://storage.googleapis.com/learn_pd_like_tidyverse/gapminder.xlsx"
gapminder = pd.read_excel(xlsx_file)
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
gapminder[gapminder["country"] == "Taiwan"]
# Out:
#      country continent  year  lifeExp       pop     gdpPercap
# 1500  Taiwan      Asia  1952    58.50   8550362   1206.947913
# 1501  Taiwan      Asia  1957    62.40  10164215   1507.861290
# 1502  Taiwan      Asia  1962    65.20  11918938   1822.879028
# 1503  Taiwan      Asia  1967    67.50  13648692   2643.858681
# 1504  Taiwan      Asia  1972    69.39  15226039   4062.523897
# 1505  Taiwan      Asia  1977    70.59  16785196   5596.519826
# 1506  Taiwan      Asia  1982    72.16  18501390   7426.354774
# 1507  Taiwan      Asia  1987    73.40  19757799  11054.561750
# 1508  Taiwan      Asia  1992    74.26  20686918  15215.657900
# 1509  Taiwan      Asia  1997    75.25  21628605  20206.820980
# 1510  Taiwan      Asia  2002    76.99  22454239  23235.423290
# 1511  Taiwan      Asia  2007    78.40  23174294  28718.276840

# %%
gapminder[(gapminder["year"] == 2007)  &  (gapminder["continent"] == "Asia")]  # 多条件筛选
# Out:
#                  country continent  year  lifeExp         pop     gdpPercap
# 11           Afghanistan      Asia  2007   43.828    31889923    974.580338
# 95               Bahrain      Asia  2007   75.635      708573  29796.048340
# 107           Bangladesh      Asia  2007   64.062   150448339   1391.253792
# 227             Cambodia      Asia  2007   59.723    14131858   1713.778686
# 299                China      Asia  2007   72.961  1318683096   4959.114854
# 671     Hong Kong, China      Asia  2007   82.208     6980412  39724.978670
# 707                India      Asia  2007   64.698  1110396331   2452.210407
# 719            Indonesia      Asia  2007   70.650   223547000   3540.651564
# 731                 Iran      Asia  2007   70.964    69453570  11605.714490
# 743                 Iraq      Asia  2007   59.545    27499638   4471.061906
# 767               Israel      Asia  2007   80.745     6426679  25523.277100
# ...

# %%
gapminder[["country", "continent"]].head()
# Out:
#        country continent
# 0  Afghanistan      Asia
# 1  Afghanistan      Asia
# 2  Afghanistan      Asia
# 3  Afghanistan      Asia
# 4  Afghanistan      Asia

# %%
gapminder["country_abb"] = gapminder["country"].apply(lambda x: x[:3])
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap country_abb
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314         Afg
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030         Afg
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710         Afg
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138         Afg
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106         Afg

# %%
gapminder[gapminder["year"] == 2007][["pop"]].sum()
# Out:
# pop    6251013179
# dtype: int64

# %%
gapminder[gapminder["year"] == 2007][["lifeExp", "gdpPercap"]].mean()
# Out:
# lifeExp         67.007423
# gdpPercap    11680.071820
# dtype: float64

# %%
gapminder[gapminder["year"] == 2007].groupby("continent")["pop"].sum()
# Out:
# continent
# Africa       929539692
# Americas     898871184
# Asia        3811953827
# Europe       586098529
# Oceania       24549947
# Name: pop, dtype: int64

# %%
gapminder[gapminder["year"] == 2007].groupby("continent")[["lifeExp", "gdpPercap"]].mean()
# Out:
#              lifeExp     gdpPercap
# continent
# Africa     54.806038   3089.032605
# Americas   73.608120  11003.031625
# Asia       70.728485  12473.026870
# Europe     77.648600  25054.481636
# Oceania    80.719500  29810.188275

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use("ggplot")
gapminder_twn = gapminder[gapminder["country"] == "Taiwan"]
gapminder_twn[["year", "pop"]].plot(kind="line", x="year", y="pop",
                                   title="Pop vs Year in Taiwan", legend=False)
plt.show()

# %%
gapminder_northasia = gapminder.loc[gapminder["country"].isin(["China", "Japan", "Korea, Rep.", "Taiwan"])]
gapminder_northasia_pivot = gapminder_northasia.pivot_table(values= "lifeExp",
                                                           columns ="country", index="year")
gapminder_northasia_pivot.plot(title = "Life Expectancy in North Asia")
plt.show()

# %%
gapminder_2007 = gapminder[gapminder["year"] == 2007]
gapminder_2007[["pop", "gdpPercap", "lifeExp"]].hist(bins=20)
plt.show()

# %%
gapminder_2007[["gdpPercap"]].plot(kind="hist", title="GDP Per Capita in 2007", legend=False, bins=15)
plt.show()   # 直方图

# %%
gapminder_continent_pivot = gapminder_2007.pivot_table(values ="gdpPercap",
                                                      columns="continent", index="country")
gapminder_continent_pivot.plot(kind="hist", alpha=.5, bins=20,
                              title = "GDP Per Capita by Continent")
plt.show()

# %%
gapminder_continent_pivot.plot(kind="box", title="GDP Per Capita by Continent")
plt.show()

# %%
gapminder_2007.plot(kind="scatter", x="gdpPercap", y="lifeExp",
                   title=" Weath vs Health in 2007")
plt.show()

# %%
gapminder_2007.plot(kind="hexbin", x="gdpPercap", y="lifeExp",
                   title="weath vs health in 2007", gridsize=20)
plt.show()

# %%
summarized_df = gapminder[gapminder["year"] == 2007].groupby("continent")["pop"].sum()
summarized_df.plot(kind="barh", rot=45)
plt.show()

# %%
summarized_df = gapminder_2007.groupby("continent")[["lifeExp", "gdpPercap"]].mean()
summarized_df.plot(kind="barh", subplots = True, layout = (1,2),
                  sharex=False, sharey=True, legend =False)
plt.show()

# %%
df_grouped = gapminder.groupby("year")
df_dict = {}
for i in range(1952, 2011, 5):
    df_dict[i] = df_grouped.get_group(i).reset_index(drop = True)

gapminder_panel = pd.Panel(df_dict)
gapminder_panel
# Out:
# <class 'pandas.core.panel.Panel'>
# Dimensions: 12 (items) x 142 (major_axis) x 7 (minor_axis)
# Items axis: 1952 to 2007
# Major_axis axis: 0 to 141
# Minor_axis axis: country to country_abb

# %%
def get_data(url_list):
    df_list = []
    for url in url_list:
        df_list.append(pd.read_excel(url, sheetname = 'Data'))
    return df_list

url_list = ['https://storage.googleapis.com/learn_pd_like_tidyverse/indicator_gapminder_population.xlsx',
            'https://storage.googleapis.com/learn_pd_like_tidyverse/indicator_gapminder_gdp_per_capita_ppp.xlsx', 
            'https://storage.googleapis.com/learn_pd_like_tidyverse/indicator_life_expectancy_at_birth.xlsx']

wide_df_list = get_data(url_list)
wide_df_list[0].head()
wide_df_list[1].head()
wide_df_list[2].head()
# Out:
#          Life expectancy   1800   1801   1802   1803   1804   1805   1806  \
# 0               Abkhazia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1            Afghanistan  28.21  28.20  28.19  28.18  28.17  28.16  28.15
# 2  Akrotiri and Dhekelia    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3                Albania  35.40  35.40  35.40  35.40  35.40  35.40  35.40
# 4                Algeria  28.82  28.82  28.82  28.82  28.82  28.82  28.82
#
#     1807   1808  ...    2007  2008  2009  2010  2011  2012  2013  2014  2015  \
# 0    NaN    NaN  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  28.14  28.13  ...    52.4  52.8  53.3  53.6  54.0  54.4  54.8  54.9  53.8
# 2    NaN    NaN  ...     NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  35.40  35.40  ...    76.6  76.8  77.0  77.2  77.4  77.5  77.7  77.9  78.0
# 4  28.82  28.82  ...    75.3  75.5  75.7  76.0  76.1  76.2  76.3  76.3  76.4
#
#     2016
# 0    NaN
# 1  52.72
# 2    NaN
# 3  78.10
# ...

# %%
def get_long_df(wide_df_list):
    
    long_df_list = []
    source_var = ["Total population", "GDP per capita", "Life expectancy"]
    renamed_var = ["pop", "gdpPercap", "lifeExp"]
    for (i, old_var, new_var) in zip(range(3), source_var, renamed_var):
        df = pd.melt(wide_df_list[i], id_vars= [old_var])
        df.columns = ["country", "year", "new_var"]
        long_df_list.append(df)
    return long_df_list

long_df_list = get_long_df(wide_df_list)
long_df_list[0].head()
long_df_list[1].head()
long_df_list[2].head()
# Out:
#                  country  year  new_var
# 0               Abkhazia  1800      NaN
# 1            Afghanistan  1800    28.21
# 2  Akrotiri and Dhekelia  1800      NaN
# 3                Albania  1800    35.40
# 4                Algeria  1800    28.82

# %%
merged_df = pd.merge(long_df_list[0], long_df_list[1], on=["country", "year"])
merged_df = pd.merge(merged_df, long_df_list[2], on=["country", "year"])
merged_df = merged_df.dropna()
merged_df = merged_df.sort_values(["year", "country"])
merged_df = merged_df.reset_index(drop=True)
merged_df.head()
# Out:
#                country  year  new_var_x  new_var_y  new_var
# 0          Afghanistan  1800  3280000.0      603.0    28.21
# 1              Albania  1800   410445.0      667.0    35.40
# 2              Algeria  1800  2503218.0      716.0    28.82
# 3               Angola  1800  1567028.0      618.0    26.98
# 4  Antigua and Barbuda  1800    37000.0      757.0    33.54

# %%
merged_df.to_csv("gapminder.csv", index=False)
merged_df.to_excel("gapminder.xlsx", index=False)
